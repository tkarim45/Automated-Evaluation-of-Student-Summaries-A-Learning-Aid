# %% [markdown]
# # 0. Imports

# %%
import numpy as np
import pandas as pd

import transformers
from transformers import AutoModel, AutoTokenizer, AutoConfig, AutoModelForSequenceClassification
from transformers import DataCollatorWithPadding
from transformers import TrainingArguments, Trainer

from datasets import Dataset as Dataset_HF
from torch.utils.data import Dataset

import torch
import gc
import re

# Metrics
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

import warnings
warnings.simplefilter("ignore")
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # 1. Load Dataset

# %%
adhd_df = pd.read_csv('/kaggle/input/adhdnot-adhd-dataset/ADHD.csv')
adhd_df.head()
# Out:
#    Unnamed: 0                                               text   content  \
# 0           0  Hey, did you knwo? At the top of the socal lad...  0.863521
# 1           1  Hey, did yOU kow? Guess what? So the social go...  0.237703
# 2           2  HEy, did you know? Here's a story: The Differe...  0.378200
# 3           3  Guess what? Hey, did you know? The pharaohs, t...  0.789650
# 4           4  iN ancienct Egpt, tEy could raed and wrtie. Th...  0.495394
#
#     wording prompt_id                                    prompt_question  \
# 0  0.560241    3b9047  In complete sentences, summarize the structure...
# 1  0.500000    3b9047  In complete sentences, summarize the structure...
# 2  0.542762    3b9047  In complete sentences, summarize the structure...
# 3  0.859773    3b9047  In complete sentences, summarize the structure...
# 4  0.500000    3b9047  In complete sentences, summarize the structure...
#
#                 prompt_title  \
# 0  Egyptian Social Structure
# 1  Egyptian Social Structure
# 2  Egyptian Social Structure
# 3  Egyptian Social Structure
# 4  Egyptian Social Structure
#
#                                          prompt_text    student_id
# 0  Egyptian society was structured like a pyramid...  ded6a14b4c27
# 1  Egyptian society was structured like a pyramid...  95c8b1d33694
# 2  Egyptian society was structured like a pyramid...  55918828da86
# 3  Egyptian society was structured like a pyramid...  e70311747892
# 4  Egyptian society was structured like a pyramid...  875c0d066910

# %%
not_adhd_df = pd.read_csv('/kaggle/input/adhdnot-adhd-dataset/Not_ADHD.csv')
not_adhd_df.head()
# Out:
#    Unnamed: 0 prompt_id                                    prompt_question  \
# 0           0    3b9047  In complete sentences, summarize the structure...
# 1           1    3b9047  In complete sentences, summarize the structure...
# 2           2    3b9047  In complete sentences, summarize the structure...
# 3           3    3b9047  In complete sentences, summarize the structure...
# 4           4    3b9047  In complete sentences, summarize the structure...
#
#                 prompt_title  \
# 0  Egyptian Social Structure
# 1  Egyptian Social Structure
# 2  Egyptian Social Structure
# 3  Egyptian Social Structure
# 4  Egyptian Social Structure
#
#                                          prompt_text    student_id  \
# 0  Egyptian society was structured like a pyramid...  ded6a14b4c27
# 1  Egyptian society was structured like a pyramid...  95c8b1d33694
# 2  Egyptian society was structured like a pyramid...  55918828da86
# 3  Egyptian society was structured like a pyramid...  e70311747892
# 4  Egyptian society was structured like a pyramid...  875c0d066910
#
#                                                 text   content   wording
# 0  In the structure of the ancient Egyptian gover...  0.425078  0.519454
# 1  In the ancient Egyptian system of government, ...  0.483478  0.328477
# 2  The a try tire of ancient Egypt is they belove...  0.274036  0.320513
# 3  The pharoah is at the top and is seen as the s...  0.648103  0.771420
# 4  Different social classes were involved in this...  0.522206  0.355555

# %% [markdown]
# # 2. Data Prepocessing
#
# First, we need to remove some special symbols in the text because it has no semantic meaning.

# %%
adhd_df['text'] = adhd_df["text"].replace(re.compile(r'[\n\r\t]'), ' ', regex=True)
not_adhd_df['text'] = test["text"].replace(re.compile(r'[\n\r\t]'), ' ', regex=True)

# %% [markdown]
# # 3. Set Configuration

# %%
class CFG:
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    max_length=512
    hidden_dropout_prob=0.005
    attention_probs_dropout_prob=0.005
    model_name = "distilroberta-base"
    tokenizer = AutoTokenizer.from_pretrained('/kaggle/input/distilroberta-base')
    model = AutoModelForSequenceClassification.from_pretrained('/kaggle/input/distilroberta-base',num_labels=2,problem_type="regression").to(device)
# Out:
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at /kaggle/input/distilroberta-base and are newly initialized: ['classifier.out_proj.bias', 'classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model_config = AutoConfig.from_pretrained('/kaggle/input/distilroberta-base')
model_config.update({
        "hidden_dropout_prob": CFG.hidden_dropout_prob,
        "attention_probs_dropout_prob": CFG.attention_probs_dropout_prob,
        "num_labels": 2,
        "problem_type": "regression",
    })

# %% [markdown]
# ## Data Collector

# %%
data_collator = DataCollatorWithPadding(tokenizer=CFG.tokenizer)

# %% [markdown]
# ## Evaluation Function
#
# ![image.png](attachment:1760ad27-a14a-43f9-8fd1-5cc8242c4c13.png)

# %%
def caculate_mcrmse(eval_pred):
    predictions, labels = eval_pred
    squared_errors = np.square(predictions - labels)
    mean_squared_errors = np.mean(squared_errors, axis=0)
    rmse = np.sqrt(mean_squared_errors)

    mcrmse_value = np.mean(rmse)
    content_rmse = rmse[0]
    wording_rmse = rmse[1]
    
    return {
        "mcrmse": mcrmse_value,
        "content_rmse": content_rmse,
        "wording_rmse": wording_rmse
    }

# %%
df_train, df_valid = train_test_split(adhd_df, test_size=0.2, random_state=42, stratify=adhd_df['prompt_id'])

# %% [markdown]
# # 4. Dataset for different targets

# %%
train_content = df_train[["prompt_question", "text", "content", "wording"]]
valid_content = df_valid[["prompt_question", "text", "content", "wording"]]

df_test = adhd_df[["prompt_question","text"]]

# %% [markdown]
# **Now we need to transform the dataframe to dataset.**

# %%
train_dataset_content = Dataset_HF.from_pandas(train_content, preserve_index=False) 
valid_dataset_content = Dataset_HF.from_pandas(valid_content, preserve_index=False) 
test_dataset = Dataset_HF.from_pandas(df_test, preserve_index=False)

# %% [markdown]
# # 5. Tokenizer
#
# **We need to tokenize the text before put it into a model. We are gonna distinguish between training set and test set. If it is a training set, the tokenizer will return a dictionary including input id, attention mask, and labels.**
#
# **If it is a training set, only the input id and attention mask will be returned.**

# %%
def tokenize_function(examples,dataset='train'):
    if dataset == 'train':
        labels = [examples["content"], examples["wording"]]
        tokenized = CFG.tokenizer(examples["text"],
                                  examples["prompt_question"],
                                  padding=False,
                                  truncation=True,
                                  max_length=CFG.max_length)
        return {**tokenized,"labels": labels}
        
    elif dataset == 'test':
        tokenized = CFG.tokenizer(examples["text"],
                                  examples["prompt_question"],
                                  padding=False,
                                  truncation=True,
                                  max_length=CFG.max_length)
        
        return tokenized

# %%
train_tokenized_datasets_content = train_dataset_content.map(lambda example: tokenize_function(example, dataset='train'), batched=False)
valid_tokenized_datasets_content = valid_dataset_content.map(lambda example: tokenize_function(example, dataset='train'), batched=False)
test_tokenized_datasets_content = test_dataset.map(lambda example: tokenize_function(example,dataset='test'),batched=False)
# Out:
#   0%|          | 0/160 [00:00<?, ?ex/s]
#   0%|          | 0/40 [00:00<?, ?ex/s]
#   0%|          | 0/200 [00:00<?, ?ex/s]

# %%
gc.collect()
# Out:
# 19191

# %% [markdown]
# # 6. Training a model ADHD

# %%
training_args = TrainingArguments(
    output_dir="output",             
    per_device_train_batch_size=8,   
    per_device_eval_batch_size=4,    
    learning_rate=1.5e-5,            
    lr_scheduler_type="linear",      
    warmup_ratio=0.01,               
    num_train_epochs=15,              
    save_strategy="epoch",           
    logging_strategy="epoch",        
    evaluation_strategy="epoch",    
    load_best_model_at_end=True,     
    metric_for_best_model="mcrmse",  
    greater_is_better=False,         
    fp16=False,                      
    report_to='none',                
    save_total_limit=1               
)

trainer = Trainer(
    model=CFG.model,
    train_dataset=train_tokenized_datasets_content,
    eval_dataset=valid_tokenized_datasets_content,
    data_collator=data_collator,
    args=training_args,
    compute_metrics=caculate_mcrmse,
    tokenizer=CFG.tokenizer
)
trainer.train()

trainer.save_model("best_model")
# Out:
# You're using a RobertaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='300' max='300' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [300/300 01:24, Epoch 15/15]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Mcrmse</th>
#       <th>Content Rmse</th>
#       <th>Wording Rmse</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.227300</td>
#       <td>0.021781</td>
#       <td>0.143050</td>
#       <td>0.179352</td>
#       <td>0.106747</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.039000</td>
#       <td>0.013306</td>
#       <td>0.112730</td>
#       <td>0.137175</td>
#       <td>0.088286</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.026000</td>
#       <td>0.019947</td>
#       <td>0.134229</td>
#       <td>0.178160</td>
#       <td>0.090298</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.027300</td>
#       <td>0.016273</td>
#       <td>0.127560</td>
#       <td>0.126439</td>
#       <td>0.128680</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.021300</td>
#       <td>0.013393</td>
#       <td>0.114280</td>
#       <td>0.132516</td>
#       <td>0.096044</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.019400</td>
#       <td>0.012326</td>
#       <td>0.109368</td>
#       <td>0.128456</td>
#       <td>0.090280</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.018400</td>
#       <td>0.010416</td>
#       <td>0.100360</td>
#       <td>0.118890</td>
#       <td>0.081830</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.017800</td>
#       <td>0.010126</td>
#       <td>0.098267</td>
#       <td>0.119946</td>
#       <td>0.076587</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.016800</td>
#       <td>0.014575</td>
#       <td>0.120726</td>
#       <td>0.120708</td>
#       <td>0.120744</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.015600</td>
#       <td>0.011482</td>
#       <td>0.105600</td>
#       <td>0.123769</td>
#       <td>0.087431</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.014100</td>
#       <td>0.011184</td>
#       <td>0.103890</td>
#       <td>0.123668</td>
#       <td>0.084112</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.014100</td>
#       <td>0.009840</td>
#       <td>0.097336</td>
#       <td>0.116472</td>
#       <td>0.078199</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.014100</td>
#       <td>0.011788</td>
#       <td>0.106537</td>
#       <td>0.127461</td>
#       <td>0.085613</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.014300</td>
#       <td>0.011584</td>
#       <td>0.106160</td>
#       <td>0.123874</td>
#       <td>0.088446</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.012400</td>
#       <td>0.011793</td>
#       <td>0.107118</td>
#       <td>0.124980</td>
#       <td>0.089256</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
# Evaluate on the evaluation dataset
eval_metrics = trainer.evaluate()
eval_metrics
# Out:
# {'eval_loss': 0.009840426035225391,
#  'eval_mcrmse': 0.09733566641807556,
#  'eval_content_rmse': 0.11647187918424606,
#  'eval_wording_rmse': 0.07819944620132446,
#  'eval_runtime': 0.2561,
#  'eval_samples_per_second': 156.183,
#  'eval_steps_per_second': 39.046,
#  'epoch': 15.0}

# %% [markdown]
# # 7. Prediction

# %%
predictions = trainer.predict(test_tokenized_datasets_content)
predictions
# Out:
# PredictionOutput(predictions=array([[0.8258373 , 0.6033035 ],
#        [0.42655456, 0.5829246 ],
#        [0.3998333 , 0.50809574],
#        [0.8141424 , 0.6702635 ],
#        [0.52297604, 0.5126585 ],
#        [0.74266315, 0.6263867 ],
#        [0.40138176, 0.48999536],
#        [0.37944508, 0.47491515],
#        [0.5097633 , 0.55433905],
#        [0.42259926, 0.509009  ],
#        [0.3842362 , 0.50960064],
#        [0.85744685, 0.6798063 ],
#        [0.6487521 , 0.6836333 ],
#        [0.43682155, 0.552643  ],
#        [0.48754066, 0.56516886],
#        [0.48662892, 0.59803843],
#        [0.99253124, 0.9216479 ],
#        [0.30525675, 0.5581387 ],
#        [0.5238456 , 0.60121864],
#        [0.32350639, 0.55144715],
#        [0.47826475, 0.610345  ],
#        [0.96538424, 0.89361817],
#        [0.85891235, 0.80983096],
#        [0.55580455, 0.6309414 ],
#        [0.57696325, 0.6425321 ],
#        [0.25897995, 0.5093629 ],
#        [0.63685954, 0.6435571 ]], dtype=float32), label_ids=None, metrics={'test_runtime': 1.2233, 'test_samples_per_second': 163.496, 'test_steps_per_second': 40.874})

# %%
content_list = predictions.predictions[:, 0].tolist()
wording_list = predictions.predictions[:, 1].tolist()

# %% [markdown]
# # Train Not_adhd Model

# %%
df_train, df_valid = train_test_split(not_adhd_df, test_size=0.2, random_state=42, stratify=not_adhd_df['prompt_id'])

# %%
train_content = df_train[["prompt_question", "text", "content", "wording"]]
valid_content = df_valid[["prompt_question", "text", "content", "wording"]]

df_test = not_adhd_df[["prompt_question","text"]]

# %%
train_dataset_content = Dataset_HF.from_pandas(train_content, preserve_index=False) 
valid_dataset_content = Dataset_HF.from_pandas(valid_content, preserve_index=False) 
test_dataset = Dataset_HF.from_pandas(df_test, preserve_index=False)

# %%
def tokenize_function(examples,dataset='train'):
    if dataset == 'train':
        labels = [examples["content"], examples["wording"]]
        tokenized = CFG.tokenizer(examples["text"],
                                  examples["prompt_question"],
                                  padding=False,
                                  truncation=True,
                                  max_length=CFG.max_length)
        return {**tokenized,"labels": labels}
        
    elif dataset == 'test':
        tokenized = CFG.tokenizer(examples["text"],
                                  examples["prompt_question"],
                                  padding=False,
                                  truncation=True,
                                  max_length=CFG.max_length)
        
        return tokenized

# %%
train_tokenized_datasets_content = train_dataset_content.map(lambda example: tokenize_function(example, dataset='train'), batched=False)
valid_tokenized_datasets_content = valid_dataset_content.map(lambda example: tokenize_function(example, dataset='train'), batched=False)
test_tokenized_datasets_content = test_dataset.map(lambda example: tokenize_function(example,dataset='test'),batched=False)
# Out:
#   0%|          | 0/160 [00:00<?, ?ex/s]
#   0%|          | 0/40 [00:00<?, ?ex/s]
#   0%|          | 0/200 [00:00<?, ?ex/s]

# %%
gc.collect()
# Out:
# 575

# %%
training_args = TrainingArguments(
    output_dir="output",             
    per_device_train_batch_size=8,   
    per_device_eval_batch_size=4,    
    learning_rate=1.5e-5,            
    lr_scheduler_type="linear",      
    warmup_ratio=0.01,               
    num_train_epochs=15,              
    save_strategy="epoch",           
    logging_strategy="epoch",        
    evaluation_strategy="epoch",    
    load_best_model_at_end=True,     
    metric_for_best_model="mcrmse",  
    greater_is_better=False,         
    fp16=False,                      
    report_to='none',                
    save_total_limit=1               
)

trainer = Trainer(
    model=CFG.model,
    train_dataset=train_tokenized_datasets_content,
    eval_dataset=valid_tokenized_datasets_content,
    data_collator=data_collator,
    args=training_args,
    compute_metrics=caculate_mcrmse,
    tokenizer=CFG.tokenizer
)
trainer.train()

trainer.save_model("best_model")
# Out:
#     <div>
#
#       <progress value='300' max='300' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [300/300 01:06, Epoch 15/15]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Mcrmse</th>
#       <th>Content Rmse</th>
#       <th>Wording Rmse</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.027900</td>
#       <td>0.025222</td>
#       <td>0.157073</td>
#       <td>0.133625</td>
#       <td>0.180520</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.026800</td>
#       <td>0.024864</td>
#       <td>0.156783</td>
#       <td>0.139957</td>
#       <td>0.173609</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.023800</td>
#       <td>0.031818</td>
#       <td>0.177702</td>
#       <td>0.162220</td>
#       <td>0.193185</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.022000</td>
#       <td>0.028879</td>
#       <td>0.167954</td>
#       <td>0.142054</td>
#       <td>0.193854</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.023000</td>
#       <td>0.024735</td>
#       <td>0.156229</td>
#       <td>0.138134</td>
#       <td>0.174323</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.018500</td>
#       <td>0.019546</td>
#       <td>0.137551</td>
#       <td>0.112529</td>
#       <td>0.162573</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.015300</td>
#       <td>0.023813</td>
#       <td>0.152646</td>
#       <td>0.130011</td>
#       <td>0.175281</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.016000</td>
#       <td>0.021326</td>
#       <td>0.144913</td>
#       <td>0.126836</td>
#       <td>0.162989</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.014500</td>
#       <td>0.019923</td>
#       <td>0.139632</td>
#       <td>0.118995</td>
#       <td>0.160269</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.012800</td>
#       <td>0.021056</td>
#       <td>0.144509</td>
#       <td>0.131344</td>
#       <td>0.157675</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.012500</td>
#       <td>0.019957</td>
#       <td>0.140061</td>
#       <td>0.121634</td>
#       <td>0.158488</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.011800</td>
#       <td>0.020137</td>
#       <td>0.140303</td>
#       <td>0.119051</td>
#       <td>0.161555</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.009900</td>
#       <td>0.020328</td>
#       <td>0.140835</td>
#       <td>0.118606</td>
#       <td>0.163063</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.010300</td>
#       <td>0.019759</td>
#       <td>0.138781</td>
#       <td>0.116447</td>
#       <td>0.161116</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.011100</td>
#       <td>0.020262</td>
#       <td>0.140505</td>
#       <td>0.117693</td>
#       <td>0.163318</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
# Evaluate on the evaluation dataset
eval_metrics = trainer.evaluate()
eval_metrics
# Out:
# {'eval_loss': 0.019546348601579666,
#  'eval_mcrmse': 0.13755087554454803,
#  'eval_content_rmse': 0.11252882331609726,
#  'eval_wording_rmse': 0.1625729352235794,
#  'eval_runtime': 0.1984,
#  'eval_samples_per_second': 201.618,
#  'eval_steps_per_second': 50.405,
#  'epoch': 15.0}

# %%
predictions = trainer.predict(test_tokenized_datasets_content)
predictions
# Out:
# PredictionOutput(predictions=array([[0.43226004, 0.4315618 ],
#        [0.542861  , 0.43413386],
#        [0.33142856, 0.3428762 ],
#        [0.6771538 , 0.6102366 ],
#        [0.585866  , 0.45964393],
#        [0.91530657, 0.6393415 ],
#        [0.7799133 , 0.4958163 ],
#        [0.24551217, 0.29815078],
#        [0.65410227, 0.51633143],
#        [0.44146326, 0.3485523 ],
#        [0.3126849 , 0.3185013 ],
#        [0.24687384, 0.30016527],
#        [0.4803463 , 0.57024574],
#        [0.64050144, 0.5392771 ],
#        [0.648003  , 0.5679201 ],
#        [0.80404323, 0.6443508 ],
#        [0.755205  , 0.46475935],
#        [0.4847301 , 0.37262017],
#        [0.65167063, 0.5311907 ],
#        [0.4504611 , 0.37793112],
#        [0.31617916, 0.34274283],
#        [0.67559004, 0.54005295],
#        [0.9044731 , 0.6658863 ],
#        [0.5423657 , 0.4651054 ],
#        [0.45262668, 0.3568003 ],
#        [0.6809032 , 0.5324651 ],
#        [0.38537782, 0.31128693],
#        [0.7056734 , 0.50338465],
#        [0.29647744, 0.31074914],
#        [0.6332678 , 0.5563828 ],
#        [0.54083234, 0.37302408],
#        [0.48313594, 0.4155426 ],
#        [0.56991994, 0.45860553],
#        [0.64515686, 0.5477596 ],
#        [0.5417991 , 0.4340852 ],
#        [0.36502394, 0.30740672],
#        [0.76560265, 0.5555974 ],
#        [0.4567501 , 0.4075121 ],
#        [0.5460934 , 0.5360993 ],
#        [0.2846818 , 0.33166814],
#        [0.46317014, 0.44023338],
#        [0.53370374, 0.38674363],
#        [0.777583  , 0.48857912],
#        [0.75208324, 0.51519394],
#        [0.80789286, 0.6162252 ],
#        [0.41197944, 0.4065523 ],
#        [0.8793672 , 0.69249487],
#        [0.64085233, 0.45146853],
#        [0.2278987 , 0.29984376],
#        [0.37318835, 0.40749162],
#        [0.5414967 , 0.4359793 ],
#        [0.38897234, 0.34479216],
#        [0.7114915 , 0.5158155 ],
#        [0.2567219 , 0.3187074 ],
#        [0.47596008, 0.33698967],
#        [0.2936014 , 0.32373694],
#        [0.4328065 , 0.47291598],
#        [0.23855217, 0.25951457],
#        [0.70482534, 0.635136  ],
#        [0.30941054, 0.36005273],
#        [0.3504969 , 0.30543903],
#        [0.50810516, 0.35712254],
#        [0.8487794 , 0.6908334 ],
#        [0.75184387, 0.59812886],
#        [0.5639766 , 0.4771037 ],
#        [0.57505524, 0.47908792],
#        [0.90584475, 0.7024092 ],
#        [0.24503078, 0.31636983],
#        [0.60183024, 0.53787047],
#        [0.25979072, 0.31215212],
#        [0.534194  , 0.46126005],
#        [0.33820054, 0.36910048],
#        [0.42335585, 0.43551624],
#        [0.6210698 , 0.51388794],
#        [0.26417574, 0.3140971 ],
#        [0.28323042, 0.272782  ],
#        [0.6393162 , 0.45000732],
#        [0.41330653, 0.39246237],
#        [0.5040381 , 0.4559213 ],
#        [0.68855983, 0.6240621 ],
#        [0.26951477, 0.2782619 ],
#        [0.4868207 , 0.4715865 ],
#        [0.4417734 , 0.42892373],
#        [0.32475418, 0.35354668],
#        [0.25903547, 0.31809226],
#        [0.38731754, 0.3714345 ],
#        [0.3982739 , 0.33304042],
#        [0.34387523, 0.3051244 ],
#        [0.31138745, 0.39417493],
#        [0.8510055 , 0.52465236],
#        [0.27787563, 0.3143096 ],
#        [0.59609765, 0.52128726],
#        [0.3327765 , 0.34951982],
#        [0.8641029 , 0.7274882 ],
#        [0.5953087 , 0.55190855],
#        [0.2577099 , 0.30536276],
#        [0.63883597, 0.515867  ],
#        [0.27386206, 0.30053276],
#        [0.36375698, 0.34477407],
#        [0.33905265, 0.3223556 ],
#        [0.5494111 , 0.50150734],
#        [0.6115137 , 0.45666414],
#        [0.60724807, 0.5241721 ],
#        [0.59762126, 0.43636328],
#        [0.42569023, 0.46360737],
#        [0.540961  , 0.4875616 ],
#        [0.48472252, 0.53312176],
#        [0.30707765, 0.35564736],
#        [0.30257636, 0.4336182 ],
#        [0.4000258 , 0.40963477],
#        [0.4063465 , 0.42645806],
#        [0.20930073, 0.27709654],
#        [0.28893104, 0.285582  ],
#        [0.38474578, 0.35064477],
#        [0.35694182, 0.38168365],
#        [0.7373044 , 0.575694  ],
#        [0.58311486, 0.54634905],
#        [0.86242926, 0.8191476 ],
#        [0.5924644 , 0.5037394 ],
#        [0.58682644, 0.62646353],
#        [0.7404381 , 0.769714  ],
#        [0.29126436, 0.31277555],
#        [0.32361633, 0.29406938],
#        [0.29728562, 0.32961285],
#        [0.70978326, 0.72636867],
#        [0.47467697, 0.42553633],
#        [0.941404  , 0.80378765],
#        [0.5671217 , 0.61914086],
#        [0.20930073, 0.27709654],
#        [0.39624673, 0.3382778 ],
#        [0.59815335, 0.69266176],
#        [0.36234504, 0.45016983],
#        [0.4720562 , 0.5269465 ],
#        [0.4332326 , 0.35257077],
#        [0.43594608, 0.3577848 ],
#        [0.7263436 , 0.6930776 ],
#        [0.41718045, 0.5067123 ],
#        [0.44821927, 0.4374296 ],
#        [0.37171042, 0.35783565],
#        [0.27082956, 0.2913589 ],
#        [0.29242945, 0.3537751 ],
#        [0.67620593, 0.57871187],
#        [0.5057264 , 0.48004118],
#        [0.34975332, 0.3532292 ],
#        [0.2795304 , 0.2645649 ],
#        [0.6112198 , 0.57030535],
#        [0.31839433, 0.32717314],
#        [0.60944474, 0.5921556 ],
#        [0.33204234, 0.37427995],
#        [0.45851916, 0.48609155],
#        [0.49845454, 0.47203922],
#        [0.86526495, 0.77122384],
#        [0.6672831 , 0.68761766],
#        [0.8652689 , 0.82202035],
#        [0.35012123, 0.42133182],
#        [0.26413426, 0.3618347 ],
#        [0.8543979 , 0.6536011 ],
#        [0.36745358, 0.46253818],
#        [0.42340672, 0.5148693 ],
#        [0.7451803 , 0.64421785],
#        [0.664639  , 0.6928067 ],
#        [0.26925486, 0.40157184],
#        [0.38418138, 0.4587679 ],
#        [0.29961365, 0.35907677],
#        [0.22611344, 0.28797823],
#        [0.65071183, 0.68584925],
#        [0.45383844, 0.5091014 ],
#        [0.4422349 , 0.47117424],
#        [0.2568533 , 0.3613126 ],
#        [0.3301096 , 0.41326252],
#        [0.69962215, 0.64963454],
#        [0.6258411 , 0.584152  ],
#        [0.30232316, 0.39108923],
#        [0.42348808, 0.5118255 ],
#        [0.23476441, 0.36758903],
#        [0.5266678 , 0.607649  ],
#        [0.44966444, 0.5430248 ],
#        [0.57085115, 0.6163569 ],
#        [0.35574752, 0.48339218],
#        [0.8167702 , 0.71402884],
#        [0.30599993, 0.44856656],
#        [0.6992013 , 0.66148347],
#        [0.29222474, 0.36866894],
#        [0.2583198 , 0.37513512],
#        [0.4339762 , 0.4925437 ],
#        [0.23649661, 0.36591297],
#        [0.32509515, 0.42944205],
#        [0.36407056, 0.4397993 ],
#        [0.8657855 , 0.71948177],
#        [0.5665775 , 0.63830847],
#        [0.49516582, 0.5251118 ],
#        [0.38242286, 0.46520764],
#        [0.2535617 , 0.32336187],
#        [0.33463874, 0.41403633],
#        [0.35839832, 0.44151336],
#        [0.987605  , 0.85615075],
#        [0.82509303, 0.7295965 ],
#        [0.3864704 , 0.4502698 ],
#        [0.91192627, 0.8210673 ],
#        [0.667381  , 0.7406098 ]], dtype=float32), label_ids=None, metrics={'test_runtime': 0.9634, 'test_samples_per_second': 207.588, 'test_steps_per_second': 51.897})

# %%
content_list = predictions.predictions[:, 0].tolist()
wording_list = predictions.predictions[:, 1].tolist()
